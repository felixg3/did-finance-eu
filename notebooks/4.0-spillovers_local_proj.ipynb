# %% [markdown]
# # Spillover Effects via Local Projections

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
horizon=20
res=pd.DataFrame({"h":range(horizon+1)})
res["beta"]=np.random.normal(size=horizon+1)
res["se"]=0.1

# %%
res["upper"]=res.beta+1.64*res.se
res["lower"]=res.beta-1.64*res.se
res.plot(x="h",y="beta",yerr=1.64*res.se,figsize=(6,4));plt.tight_layout();

# %%
res.head()
# Out:
#    h      beta   se     upper     lower
# 0  0  1.043901  0.1  1.207901  0.879901
# 1  1  1.734477  0.1  1.898477  1.570477
# 2  2  0.184565  0.1  0.348565  0.020565
# 3  3  1.622488  0.1  1.786488  1.458488
# 4  4 -0.421603  0.1 -0.257603 -0.585603
